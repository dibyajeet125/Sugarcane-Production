# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Load the data
df = pd.read_csv("List of Countries by Sugarcane Production.csv")

# %%
df
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America       768.678.382
# 1             1      India           Asia       348.448.000
# 2             2      China           Asia       123.059.739
# 3             3   Thailand           Asia        87.468.496
# 4             4   Pakistan           Asia        65.450.704
# ..          ...        ...            ...               ...
# 98           98    Lebanon           Asia                97
# 99           99   Djibouti         Africa                53
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3.668,531        10.226.205             75.167,5
# 1                       260721         4.950.000             70.393,5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  103 non-null    int64
#  1   Country                     103 non-null    object
#  2   Continent                   103 non-null    object
#  3   Production (Tons)           103 non-null    object
#  4   Production per Person (Kg)  103 non-null    object
#  5   Acreage (Hectare)           102 non-null    object
#  6   Yield (Kg / Hectare)        102 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.8+ KB

# %%
# Dropping the Unnamed: 0 column
df = df.drop("Unnamed: 0", axis = 1)

# %%
# Changing the data type of production from object to int
df.isnull().sum()
# Out:
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %%
# Dropping the rows with null values
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             0
# Yield (Kg / Hectare)          0
# dtype: int64

# %%
# Replcaing "."/"," with ""/"."  respectively
df["Production (Tons)"] = df["Production (Tons)"].str.replace(".","")
df["Production per Person (Kg)"] = df["Production per Person (Kg)"].str.replace(".","").str.replace(",",".")
df["Acreage (Hectare)"] = df["Acreage (Hectare)"].str.replace(".","")
df["Yield (Kg / Hectare)"]= df["Yield (Kg / Hectare)"].str.replace(".","").str.replace(",",".")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_27004\73079891.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Production (Tons)"] = df["Production (Tons)"].str.replace(".","")
# C:\Users\DELL\AppData\Local\Temp\ipykernel_27004\73079891.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Production per Person (Kg)"] = df["Production per Person (Kg)"].str.replace(".","").str.replace(",",".")
# C:\Users\DELL\AppData\Local\Temp\ipykernel_27004\73079891.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
df
# Out:
#        Country      Continent Production (Tons) Production per Person (Kg)  \
# 0       Brazil  South America         768678382                   3668.531
# 1        India           Asia         348448000                     260721
# 2        China           Asia         123059739                      88287
# 3     Thailand           Asia          87468496                   1264.303
# 4     Pakistan           Asia          65450704                     324219
# ..         ...            ...               ...                        ...
# 97       Spain         Europe               394                          8
# 98     Lebanon           Asia                97                         16
# 100  Singapore           Asia                50                          9
# 101      Samoa        Oceania                12                          6
# 102      Syria           Asia                 1                          0
#
#     Acreage (Hectare) Yield (Kg / Hectare)
# ...

# %%
# Renaming the columns
df.rename(columns= {"Production (Tons)": "Production(Tons)"}, inplace = True)
df.rename(columns= {"Production per Person (Kg)": "Production_per_person(Kg)"}, inplace = True)
df.rename(columns= {"Acreage (Hectare)": "Acreage(Hectare)"}, inplace = True)
df.rename(columns= {"Yield (Kg / Hectare)": "Yield(Kg/Hectare)"}, inplace = True)

# %%
# Changing the data type of production from object to float
df["Production(Tons)"] = df["Production(Tons)"].astype(float)
df["Production_per_person(Kg)"] = df["Production_per_person(Kg)"].astype(float)
df["Acreage(Hectare)"] = df["Acreage(Hectare)"].astype(float)
df["Yield(Kg/Hectare)"] = df["Yield(Kg/Hectare)"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102 entries, 0 to 102
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    102 non-null    object
#  1   Continent                  102 non-null    object
#  2   Production(Tons)           102 non-null    float64
#  3   Production_per_person(Kg)  102 non-null    float64
#  4   Acreage(Hectare)           102 non-null    float64
#  5   Yield(Kg/Hectare)          102 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 5.6+ KB

# %%
# Descrptive statistics of numerical columns
df.describe().T
# Out:
#                            count          mean           std   min        25%  \
# Production(Tons)           102.0  1.850372e+07  8.419149e+07   1.0  62518.750
# Production_per_person(Kg)  102.0  1.129524e+05  1.766513e+05   0.0   3671.910
# Acreage(Hectare)           102.0  2.498981e+05  1.137003e+06   0.0   1104.000
# Yield(Kg/Hectare)          102.0  5.262808e+04  3.050468e+04  10.0  29072.025
#
#                                   50%         75%          max
# Production(Tons)           1440044.00  6426823.75  768678382.0
# Production_per_person(Kg)    25572.50   146384.75     951087.0
# Acreage(Hectare)             16558.00    80474.00   10226205.0
# Yield(Kg/Hectare)            54108.95    73282.70     129049.3

# %%
# Descriptive statistics of categorical columns
df.describe(include = "object").T
# Out:
#           count unique     top freq
# Country     102    102  Brazil    1
# Continent   102      6  Africa   38

# %% [markdown]
# #### Univariate analysis

# %%
# Counting the number of countries in each continent
df["Continent"].value_counts()
# Out:
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: Continent, dtype: int64

# %%
df["Continent"].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %%
# Plotting the distribution of numerical columns
plt.figure(figsize = (10,10))
plt.subplot(2,2,1)
sns.distplot(df["Production(Tons)"])
plt.title("Production(Tons)")
plt.subplot(2,2,2)
sns.distplot(df["Production_per_person(Kg)"])
plt.title("Production_per_person(Kg)")
plt.subplot(2,2,3)
sns.distplot(df["Acreage(Hectare)"])
plt.title("Acreage(Hectare)")
plt.subplot(2,2,4)
sns.distplot(df["Yield(Kg/Hectare)"])
plt.title("Yield(Kg/Hectare)")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_27004\1030093799.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Production(Tons)"])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_27004\1030093799.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# #### Bivariate analysis

# %%
# Sugarcane production in each country
df_bi = df[["Country","Production(Tons)"]].set_index("Country")

# %%
df_bi
# Out:
#            Production(Tons)
# Country
# Brazil          768678382.0
# India           348448000.0
# China           123059739.0
# Thailand         87468496.0
# Pakistan         65450704.0
# ...                     ...
# Spain                 394.0
# Lebanon                97.0
# Singapore              50.0
# Samoa                  12.0
# Syria                   1.0
#
# [102 rows x 1 columns]

# %%
plt.figure(figsize = (8,8))
df_bi["Production(Tons)"].plot(kind="pie", autopct="%.2f%%", labels=df_bi.index)
plt.title("Sugarcane production in each country")
# Out:
# Text(0.5, 1.0, 'Sugarcane production in each country')

# %%
import matplotlib.ticker as mticker

df[["Country","Production(Tons)"]].set_index("Country").sort_values("Production(Tons)", ascending = False).head(15).plot(kind = "bar")
plt.ylabel("Production(Tons)")

# Format the y-axis to show regular numbers instead of scientific notation
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))

# %%
# Land acreage in top 15 country
df[["Country","Acreage(Hectare)"]].set_index("Country").sort_values("Acreage(Hectare)", ascending = False).head(15).plot(kind = "bar")
plt.ylabel("Acreage(Hectare)")

# Format the y-axis to show regular numbers instead of scientific notation
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))

# %%
# Top 15 country yield(Kg/Hectare)
df[["Country","Yield(Kg/Hectare)"]].set_index("Country").sort_values("Yield(Kg/Hectare)", ascending = False).head(15).plot(kind = "bar")
plt.ylabel("Yield(Kg/Hectare)")

# Format the y-axis to show regular numbers instead of scientific notation
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))

# %%
# Sugarcane production/person in top 15 country
df[["Country","Production_per_person(Kg)"]].set_index("Country").sort_values("Production_per_person(Kg)", ascending = False).head(15).plot(kind = "bar")
plt.ylabel("Production_per_person(Kg)")

# Format the y-axis to show regular numbers instead of scientific notation
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))

# %%
# Correlation
df.corr()
sns.heatmap(df.corr(), annot = True, cmap = "coolwarm")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_27004\4233646132.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
# C:\Users\DELL\AppData\Local\Temp\ipykernel_27004\4233646132.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True, cmap = "coolwarm")
# <Axes: >

# %%
# Scatter plot of production and land acreage in each country
sns.scatterplot(data = df, x = "Acreage(Hectare)", y = "Production(Tons)", hue = "Continent" )

# Format the y-axis and x-axis to show regular numbers instead of scientific notation
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))
plt.gca().xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))

# %%
# Scatter plot of production and yield in each country
sns.scatterplot(data = df, x = "Yield(Kg/Hectare)" , y = "Production(Tons)", hue = "Continent")

# Format the y-axis to show regular numbers instead of scientific notation
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))

# %%
# Anaslysis of Continent
df_continent = df.groupby("Continent").sum()
df_continent
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_27004\2113032058.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_continent = df.groupby("Continent").sum()
#                Production(Tons)  Production_per_person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# South America       865588126.0                3505531.738        11369236.0
#
#                Yield(Kg/Hectare)
# Continent
# ...

# %%
df_continent["number_of_countries"] = df.groupby("Continent").count()["Country"]
df_continent
# Out:
#                Production(Tons)  Production_per_person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# South America       865588126.0                3505531.738        11369236.0
#
#                Yield(Kg/Hectare)  number_of_countries
# Continent
# Africa                 2142107.5                   38
# Asia                   1171871.4                   25
# Europe                  131870.9                    2
# North America          1082602.4                   22
# Oceania                 162419.1                    4
# South America           677192.7                   11

# %%
# Sugarcane production in each continent
df_continent["Production(Tons)"].sort_values(ascending =  False).plot(kind = "bar")
plt.ylabel("Production(Tons)")

# Format the y-axis to show regular numbers instead of scientific notation
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))# Format the y-axis to show regular numbers instead of scientific notation

# %%
plt.figure(figsize = (12,12))
df_continent["Production(Tons)"].plot(kind="pie", autopct="%.2f%%")
plt.title("Sugarcane production in each continent")
# Out:
# Text(0.5, 1.0, 'Sugarcane production in each continent')

# %%
# Number of countries in each continent
df_continent["number_of_countries"].sort_values(ascending =  False).plot(kind = "bar")
plt.ylabel("number_of_countries")
# Out:
# Text(0, 0.5, 'number_of_countries')

# %%
# Correlation
df_continent.corr()
sns.heatmap(df_continent.corr(), annot = True, cmap = "coolwarm")
# Out:
# <Axes: >

# %%
# Scatter plot of production and land acreage in each continent
sns.scatterplot(data = df_continent,x = "Acreage(Hectare)", y= "Production(Tons)", hue = "Continent")

# Format the y-axis and x-axis to show regular numbers instead of scientific notation
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))
plt.gca().xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))

# %%
plt.figure(figsize = (9,5))
# Scatter plot of production and yield in each continent
sns.scatterplot(data = df_continent, x = "Yield(Kg/Hectare)" , y = "Production(Tons)",  hue = "Continent")

# Format the y-axis and x-axis to show regular numbers instead of scientific notation
plt.gca().yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))
plt.gca().xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{int(x):,}'))
